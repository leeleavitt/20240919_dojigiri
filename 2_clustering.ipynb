# %%
# %load_ext autoreload
# %autoreload 2
import os
from dotenv import load_dotenv
load_dotenv()
print(os.environ["DATABASE_URL"])
from shomei.models import SessionLocal
from shomei.clustering_runner import Clustering
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# local-stage

# %%
clustering = Clustering(
    project_code = "TST002",
    project_type = "biopharma",
    description= "HumanWB",
    gating_fcs_set_version="v04",
    clustering_fcs_set_version="v01",
    top_level_populations=["nonGRAN"],
    k_values=[25, 30],
    db_session=SessionLocal()
)

# %%
clustering.initialize()
# Out:
# 2024-09-25 14:56:09,458 - INFO - S3_BUCKET env OK
# 2024-09-25 14:56:09,459 - INFO - Bucket: tokuprofile-teiko
# 2024-09-25 14:56:09,460 - WARNING - Clustering fcs directory TST002/fcs/v04/clustering/v01/clustering_fcs exists
# 2024-09-25 14:56:09,460 - INFO - Local clustering fcs directory: TST002/fcs/v04/clustering/v01/clustering_fcs
# 2024-09-25 14:56:09,461 - WARNING - Clustering inputs directory TST002/fcs/v04/clustering/v01/clustering_inputs exists
# 2024-09-25 14:56:09,461 - INFO - Local clustering input directory: TST002/fcs/v04/clustering/v01/clustering_inputs
# 2024-09-25 14:56:09,462 - WARNING - Clustering results directory TST002/fcs/v04/clustering/v01/clustering_results exists
# 2024-09-25 14:56:09,884 - WARNING - Output directory s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_fcs already exists
# 2024-09-25 14:56:09,962 - WARNING - Output directory s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_inputs already exists
# 2024-09-25 14:56:10,037 - INFO - Creating s3 directory s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_results
# 2024-09-25 14:56:10,038 - INFO - Project clustering FCS set: s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_fcs
# 2024-09-25 14:56:10,050 - INFO - Found credentials in environment variables.
# 2024-09-25 14:56:10,431 - INFO - Cellengine path where the experiment will be created: ['6078b8b7396ead440ecdc88e', '66f33549b2658aeddb9323a7']
# 2024-09-25 14:56:10,644 - INFO - Experiment with the name TST002_HumanWB_v04_latest already exists in cellengine under cell engine path biopharma/TST002. Skipping experiment creation.
# 2024-09-25 14:56:10,645 - INFO - CellEngine experiment: TST002_HumanWB_v04_latest

# %%
clustering.generate_clustering_input_files()
# Out:
# 2024-09-25 11:47:11,477 - INFO - Generating all QCV clustering input files
# 2024-09-25 11:47:11,478 - INFO -     Generating QCV clustering input file for quantile 0.25
# 2024-09-25 11:47:11,479 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:47:11,536 - INFO - Found credentials in environment variables.
# 2024-09-25 11:47:11,745 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:47:11,746 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:47:11,802 - INFO - Found credentials in environment variables.
# 2024-09-25 11:47:12,001 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:47:12,001 - INFO - Getting experiment 66f3375057d2a59bbbc657db
# 2024-09-25 11:47:12,211 - INFO - Channel Time is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,211 - INFO - Channel Event_length is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,211 - INFO - Channel Center is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,212 - INFO - Channel Offset is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,212 - INFO - Channel Width is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,213 - INFO - Channel Residual is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,213 - INFO - Channel beadDist is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:47:12,213 - INFO - Getting QCVs for quantile 0.25
# 2024-09-25 11:47:12,214 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:47:12,268 - INFO - Found credentials in environment variables.
# 2024-09-25 11:47:12,463 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:47:12,470 - INFO - Found credentials in environment variables.
# 2024-09-25 11:47:12,790 - WARNING - Population CELL is a terminal gate but has no parent. Skipping
# 2024-09-25 11:53:24,412 - INFO -     Saved QCVs for quantile 0.25 to TST002/fcs/v04/clustering/v01/clustering_inputs/quantile-low.tsv
# 2024-09-25 11:53:26,744 - INFO -     Generating QCV clustering input file for quantile 0.5
# 2024-09-25 11:53:26,745 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:53:26,855 - INFO - Found credentials in environment variables.
# 2024-09-25 11:53:27,102 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:53:27,103 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:53:27,162 - INFO - Found credentials in environment variables.
# 2024-09-25 11:53:27,377 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:53:27,378 - INFO - Getting experiment 66f3375057d2a59bbbc657db
# 2024-09-25 11:53:27,602 - INFO - Channel Time is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,603 - INFO - Channel Event_length is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,604 - INFO - Channel Center is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,604 - INFO - Channel Offset is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,604 - INFO - Channel Width is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,605 - INFO - Channel Residual is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,605 - INFO - Channel beadDist is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:53:27,606 - INFO - Getting QCVs for quantile 0.5
# 2024-09-25 11:53:27,606 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:53:27,662 - INFO - Found credentials in environment variables.
# 2024-09-25 11:53:27,861 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:53:27,872 - INFO - Found credentials in environment variables.
# 2024-09-25 11:53:28,199 - WARNING - Population CELL is a terminal gate but has no parent. Skipping
# 2024-09-25 11:59:06,670 - INFO -     Saved QCVs for quantile 0.5 to TST002/fcs/v04/clustering/v01/clustering_inputs/median-channel-value.tsv
# 2024-09-25 11:59:08,700 - INFO -     Generating QCV clustering input file for quantile 0.75
# 2024-09-25 11:59:08,701 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:59:08,775 - INFO - Found credentials in environment variables.
# 2024-09-25 11:59:09,065 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:59:09,066 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:59:09,122 - INFO - Found credentials in environment variables.
# 2024-09-25 11:59:09,332 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:59:09,332 - INFO - Getting experiment 66f3375057d2a59bbbc657db
# 2024-09-25 11:59:09,561 - INFO - Channel Time is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,562 - INFO - Channel Event_length is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,562 - INFO - Channel Center is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,563 - INFO - Channel Offset is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,563 - INFO - Channel Width is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,564 - INFO - Channel Residual is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,564 - INFO - Channel beadDist is in the list of skipped channels ['Time', 'Event_length', 'Center', 'Offset', 'Width', 'Residual', 'beadDist', 'SSC-H', 'SSC-A', 'FSC-H', 'FSC-A', 'SSC-B-H', 'SSC-B-A'], skipping
# 2024-09-25 11:59:09,564 - INFO - Getting QCVs for quantile 0.75
# 2024-09-25 11:59:09,565 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:59:09,620 - INFO - Found credentials in environment variables.
# 2024-09-25 11:59:09,827 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 11:59:09,837 - INFO - Found credentials in environment variables.
# 2024-09-25 11:59:10,203 - WARNING - Population CELL is a terminal gate but has no parent. Skipping
# 2024-09-25 12:06:32,731 - INFO -     Saved QCVs for quantile 0.75 to TST002/fcs/v04/clustering/v01/clustering_inputs/quantile-high.tsv
# 2024-09-25 12:06:35,818 - INFO - Generating samples metadata clustering input file
# 2024-09-25 12:06:36,639 - INFO - Saved samples metadata clustering input file to TST002/fcs/v04/clustering/v01/clustering_inputs/sample_metadata.tsv
# 2024-09-25 12:06:36,640 - INFO - Generating cell population tsv
# 2024-09-25 12:06:36,653 - INFO - Uploading clustering inputs to s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_inputs
# 2024-09-25 12:06:48,439 - INFO - Clustering input files generated

# %%
clustering.generate_clustering_fcs_files()
# Out:
# 2024-09-25 12:10:42,681 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:42,735 - INFO - Found credentials in environment variables.
# 2024-09-25 12:10:42,936 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:42,937 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:42,991 - INFO - Found credentials in environment variables.
# 2024-09-25 12:10:43,184 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:43,185 - INFO - Getting experiment 66f3375057d2a59bbbc657db
# 2024-09-25 12:10:43,394 - INFO - Finding population ID for top level population nonGRAN
# 2024-09-25 12:10:43,401 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:43,458 - INFO - Found credentials in environment variables.
# 2024-09-25 12:10:43,647 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:43,648 - INFO - Getting latest experiment revision id for experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:43,708 - INFO - Found credentials in environment variables.
# 2024-09-25 12:10:43,910 - INFO - Checking if experiment 66f3375057d2a59bbbc657db is a child of experiment 66f3372d2c090e44e8663b43
# 2024-09-25 12:10:43,910 - INFO - Getting experiment 66f3375057d2a59bbbc657db
# 2024-09-25 12:10:44,056 - INFO - Saving 37 FCS files with only top level population
# 2024-09-25 12:10:44,056 - INFO -    Top level populations: ['nonGRAN']
# 2024-09-25 12:10:44,057 - INFO -     Saving FCS file 1 of 37
# 2024-09-25 12:10:44,342 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:44,638 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop01_nonGRAN.fcs
# 2024-09-25 12:10:44,638 - INFO -     Saving FCS file 2 of 37
# 2024-09-25 12:10:44,995 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:45,406 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop02_nonGRAN.fcs
# 2024-09-25 12:10:45,407 - INFO -     Saving FCS file 3 of 37
# 2024-09-25 12:10:45,788 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:46,202 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop03_nonGRAN.fcs
# 2024-09-25 12:10:46,203 - INFO -     Saving FCS file 4 of 37
# 2024-09-25 12:10:46,672 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:47,161 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop04_nonGRAN.fcs
# 2024-09-25 12:10:47,163 - INFO -     Saving FCS file 5 of 37
# 2024-09-25 12:10:47,475 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:47,720 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop05_nonGRAN.fcs
# 2024-09-25 12:10:47,721 - INFO -     Saving FCS file 6 of 37
# 2024-09-25 12:10:48,099 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:48,557 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop06_nonGRAN.fcs
# 2024-09-25 12:10:48,558 - INFO -     Saving FCS file 7 of 37
# 2024-09-25 12:10:49,070 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:49,676 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop07_nonGRAN.fcs
# 2024-09-25 12:10:49,679 - INFO -     Saving FCS file 8 of 37
# 2024-09-25 12:10:50,097 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:50,605 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop08_nonGRAN.fcs
# 2024-09-25 12:10:50,606 - INFO -     Saving FCS file 9 of 37
# 2024-09-25 12:10:51,181 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:51,730 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop09_nonGRAN.fcs
# 2024-09-25 12:10:51,731 - INFO -     Saving FCS file 10 of 37
# 2024-09-25 12:10:52,195 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:52,658 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop10_nonGRAN.fcs
# 2024-09-25 12:10:52,659 - INFO -     Saving FCS file 11 of 37
# 2024-09-25 12:10:53,097 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:53,518 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop11_nonGRAN.fcs
# 2024-09-25 12:10:53,518 - INFO -     Saving FCS file 12 of 37
# 2024-09-25 12:10:53,928 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:54,182 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop12_nonGRAN.fcs
# 2024-09-25 12:10:54,183 - INFO -     Saving FCS file 13 of 37
# 2024-09-25 12:10:54,444 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:54,604 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop13_nonGRAN.fcs
# 2024-09-25 12:10:54,605 - INFO -     Saving FCS file 14 of 37
# 2024-09-25 12:10:54,885 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:55,162 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P01_Pop14_nonGRAN.fcs
# 2024-09-25 12:10:55,164 - INFO -     Saving FCS file 15 of 37
# 2024-09-25 12:10:55,471 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:55,752 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop01_nonGRAN.fcs
# 2024-09-25 12:10:55,753 - INFO -     Saving FCS file 16 of 37
# 2024-09-25 12:10:55,980 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:56,178 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop02_nonGRAN.fcs
# 2024-09-25 12:10:56,178 - INFO -     Saving FCS file 17 of 37
# 2024-09-25 12:10:56,443 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:56,711 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop03_nonGRAN.fcs
# 2024-09-25 12:10:56,712 - INFO -     Saving FCS file 18 of 37
# 2024-09-25 12:10:57,045 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:57,284 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop04_nonGRAN.fcs
# 2024-09-25 12:10:57,286 - INFO -     Saving FCS file 19 of 37
# 2024-09-25 12:10:57,684 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:58,188 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop05_nonGRAN.fcs
# 2024-09-25 12:10:58,189 - INFO -     Saving FCS file 20 of 37
# 2024-09-25 12:10:58,526 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:58,841 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop06_nonGRAN.fcs
# 2024-09-25 12:10:58,841 - INFO -     Saving FCS file 21 of 37
# 2024-09-25 12:10:59,184 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:59,563 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop07_nonGRAN.fcs
# 2024-09-25 12:10:59,564 - INFO -     Saving FCS file 22 of 37
# 2024-09-25 12:10:59,757 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:10:59,860 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop08_nonGRAN.fcs
# 2024-09-25 12:10:59,861 - INFO -     Saving FCS file 23 of 37
# 2024-09-25 12:11:00,294 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:00,778 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop09_nonGRAN.fcs
# 2024-09-25 12:11:00,778 - INFO -     Saving FCS file 24 of 37
# 2024-09-25 12:11:01,025 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:01,119 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop10_nonGRAN.fcs
# 2024-09-25 12:11:01,119 - INFO -     Saving FCS file 25 of 37
# 2024-09-25 12:11:01,444 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:01,797 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop11_nonGRAN.fcs
# 2024-09-25 12:11:01,798 - INFO -     Saving FCS file 26 of 37
# 2024-09-25 12:11:02,118 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:02,599 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop12_nonGRAN.fcs
# 2024-09-25 12:11:02,600 - INFO -     Saving FCS file 27 of 37
# 2024-09-25 12:11:02,927 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:03,167 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop13_nonGRAN.fcs
# 2024-09-25 12:11:03,168 - INFO -     Saving FCS file 28 of 37
# 2024-09-25 12:11:03,554 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:03,757 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P02_Pop14_nonGRAN.fcs
# 2024-09-25 12:11:03,758 - INFO -     Saving FCS file 29 of 37
# 2024-09-25 12:11:04,300 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:05,053 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop05_nonGRAN.fcs
# 2024-09-25 12:11:05,057 - INFO -     Saving FCS file 30 of 37
# 2024-09-25 12:11:05,325 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:05,585 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop06_nonGRAN.fcs
# 2024-09-25 12:11:05,586 - INFO -     Saving FCS file 31 of 37
# 2024-09-25 12:11:05,883 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:06,238 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop07_nonGRAN.fcs
# 2024-09-25 12:11:06,239 - INFO -     Saving FCS file 32 of 37
# 2024-09-25 12:11:06,522 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:06,625 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop08_nonGRAN.fcs
# 2024-09-25 12:11:06,626 - INFO -     Saving FCS file 33 of 37
# 2024-09-25 12:11:07,064 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:07,305 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop09_nonGRAN.fcs
# 2024-09-25 12:11:07,307 - INFO -     Saving FCS file 34 of 37
# 2024-09-25 12:11:07,474 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:07,538 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop10_nonGRAN.fcs
# 2024-09-25 12:11:07,539 - INFO -     Saving FCS file 35 of 37
# 2024-09-25 12:11:07,874 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:08,225 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop11_nonGRAN.fcs
# 2024-09-25 12:11:08,226 - INFO -     Saving FCS file 36 of 37
# 2024-09-25 12:11:08,465 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:08,606 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop12_nonGRAN.fcs
# 2024-09-25 12:11:08,606 - INFO -     Saving FCS file 37 of 37
# 2024-09-25 12:11:08,888 - INFO -      Exported FCS file with top level population nonGRAN
# 2024-09-25 12:11:09,141 - INFO -      Saved FCS file to TST002/fcs/v04/clustering/v01/clustering_fcs/AXA003_P03_Pop13_nonGRAN.fcs
# 2024-09-25 12:11:09,142 - INFO - Uploading FCS files to s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_fcs
# 2024-09-25 12:11:47,279 - INFO - Clustering FCS files generated and uploaded to S3

# %%
clustering.run_clustering()
# Out:
# 2024-09-25 14:56:11,822 - WARNING - Clustering fcs set s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_fcs already exists
# 2024-09-25 14:56:11,823 - WARNING - Clustering fcs input s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_inputs already exists
# 2024-09-25 14:56:11,823 - WARNING - Clustering results s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_results already exists
# 2024-09-25 14:56:11,824 - INFO - Running R clustering script
# 2024-09-25 14:56:12,081 - INFO - Loading required package: tidyverse
#
# 2024-09-25 14:56:12,669 - INFO - ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
#
# 2024-09-25 14:56:12,669 - INFO - ✔ dplyr     1.1.4     ✔ readr     2.1.5
#
# 2024-09-25 14:56:12,670 - INFO - ✔ forcats   1.0.0     ✔ stringr   1.5.1
#
# 2024-09-25 14:56:12,670 - INFO - ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
#
# 2024-09-25 14:56:12,670 - INFO - ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
#
# 2024-09-25 14:56:12,670 - INFO - ✔ purrr     1.0.2
#
# 2024-09-25 14:56:12,717 - INFO - ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
#
# 2024-09-25 14:56:12,718 - INFO - ✖ dplyr::filter() masks stats::filter()
#
# 2024-09-25 14:56:12,718 - INFO - ✖ dplyr::lag()    masks stats::lag()
#
# 2024-09-25 14:56:12,718 - INFO - ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# 2024-09-25 14:56:12,721 - INFO - Loading required package: flowCore
#
# 2024-09-25 14:56:13,463 - INFO - Loading required package: tokuprofile
#
# 2024-09-25 14:56:13,510 - INFO - Loading required package: Spectre
#
# 2024-09-25 14:56:13,518 - INFO - Loading required package: vroom
#
# 2024-09-25 14:56:13,605 - INFO -
#
# 2024-09-25 14:56:13,606 - INFO - Attaching package: ‘vroom’
#
# 2024-09-25 14:56:13,606 - INFO -
#
# 2024-09-25 14:56:13,606 - INFO - The following objects are masked from ‘package:readr’:
#
# 2024-09-25 14:56:13,606 - INFO -
#
# 2024-09-25 14:56:13,607 - INFO -     as.col_spec, col_character, col_date, col_datetime, col_double,
#
# 2024-09-25 14:56:13,607 - INFO -     col_factor, col_guess, col_integer, col_logical, col_number,
#
# 2024-09-25 14:56:13,607 - INFO -     col_skip, col_time, cols, cols_condense, cols_only, date_names,
#
# 2024-09-25 14:56:13,607 - INFO -     date_names_lang, date_names_langs, default_locale, fwf_cols,
#
# 2024-09-25 14:56:13,607 - INFO -     fwf_empty, fwf_positions, fwf_widths, locale, output_column,
#
# 2024-09-25 14:56:13,608 - INFO -     problems, spec
#
# 2024-09-25 14:56:13,608 - INFO -
#
# 2024-09-25 14:56:13,608 - INFO - Loading required package: caret
#
# 2024-09-25 14:56:13,609 - INFO - Loading required package: lattice
#
# 2024-09-25 14:56:14,518 - INFO -
#
# 2024-09-25 14:56:14,518 - INFO - Attaching package: ‘caret’
#
# 2024-09-25 14:56:14,518 - INFO -
#
# 2024-09-25 14:56:14,519 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-25 14:56:14,519 - INFO -
#
# 2024-09-25 14:56:14,519 - INFO -     lift
#
# 2024-09-25 14:56:14,519 - INFO -
#
# 2024-09-25 14:56:14,520 - INFO - Loading required package: ggridges
#
# 2024-09-25 14:56:14,535 - INFO - Warning messages:
#
# 2024-09-25 14:56:14,536 - INFO - 1: replacing previous import ‘data.table::first’ by ‘dplyr::first’ when loading ‘tokuprofile’
#
# 2024-09-25 14:56:14,536 - INFO - 2: replacing previous import ‘data.table::last’ by ‘dplyr::last’ when loading ‘tokuprofile’
#
# 2024-09-25 14:56:14,536 - INFO - 3: replacing previous import ‘data.table::between’ by ‘dplyr::between’ when loading ‘tokuprofile’
#
# 2024-09-25 14:56:14,537 - INFO - 4: replacing previous import ‘data.table::transpose’ by ‘purrr::transpose’ when loading ‘tokuprofile’
#
# 2024-09-25 14:56:14,592 - INFO - [1] 25 30
#
# 2024-09-25 14:56:14,593 - INFO - Data prep started
#
# 2024-09-25 14:56:40,816 - INFO - Joining with `by = join_by(fcsFileId, file_name, populationId, population_name,
#
# 2024-09-25 14:56:40,818 - INFO - uniquePopulationName, parent_population_name, parentPopulationId, event_count,
#
# 2024-09-25 14:56:40,818 - INFO - channel, marker_name, sample_id, sample_name, project_code,
#
# 2024-09-25 14:56:40,818 - INFO - benchling_sample_name, sample_type, is_control, timepoint_id, sample_date,
#
# 2024-09-25 14:56:40,818 - INFO - subject_name, species, condition, subject_properties_dose)`
#
# 2024-09-25 14:56:40,941 - INFO - Preparing fcs files for clustering
#
# 2024-09-25 14:56:50,171 - INFO - Time: 2024-09-25 14:56:50.170137
#
# 2024-09-25 14:56:50,173 - INFO - Processing k 25.
#
# 2024-09-25 14:56:50,174 - INFO - Output directory: TST002/fcs/v04/clustering/v01/clustering_results/k25
#
# 2024-09-25 15:00:15,184 - INFO - time elapsed: 3.41012069781621
#
# 2024-09-25 15:00:31,027 - INFO - number of clusters: 42
#
# 2024-09-25 15:00:31,031 - INFO - Processing k 25 took 3.68095631599426
#
# 2024-09-25 15:00:31,033 - INFO - Time: 2024-09-25 15:00:31.027999
#
# 2024-09-25 15:00:31,034 - INFO - Processing k 30.
#
# 2024-09-25 15:00:31,034 - INFO - Output directory: TST002/fcs/v04/clustering/v01/clustering_results/k30
#
# 2024-09-25 15:05:54,583 - INFO - time elapsed: 5.3922331849734
#
# 2024-09-25 15:06:10,080 - INFO - number of clusters: 38
#
# 2024-09-25 15:06:10,088 - INFO - Processing k 30 took 5.6508820494016
#
# 2024-09-25 15:06:13,221 - INFO - Time: 2024-09-25 15:06:13.219507
#
# 2024-09-25 15:06:13,224 - INFO - Processing k 25.
#
# 2024-09-25 15:06:13,225 - INFO - Processing filtered 0.05
#
# 2024-09-25 15:06:13,226 - INFO - Minimum percentage of 0.05 was provided so we are calculating cluster sizes as percentag of total, filtering out events belonging to clusters under that size, and then re-calculating cluster sizes
#
# 2024-09-25 15:06:18,780 - INFO - Assigning clusters to cell types.
#
# 2024-09-25 15:06:24,151 - INFO - Checking cell population assignments and writing the set of flagged clusters.
#
# 2024-09-25 15:06:24,205 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:06:24,206 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:06:24,209 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:06:24,264 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:06:24,265 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:06:29,276 - INFO - Reassigning flagged clusters to cell types with the second highest cosine similarity score.
#
# 2024-09-25 15:06:30,411 - INFO - reassigning cluster 13
#
# 2024-09-25 15:06:30,412 - INFO - from NK - 0.938091099859113 to CD16_NK - 0.936893974191022
#
# 2024-09-25 15:06:30,413 - INFO -
#
# 2024-09-25 15:06:30,413 - INFO - reassigning cluster 19
#
# 2024-09-25 15:06:30,414 - INFO - from cMONO - 0.973017988175066 to CD33hi_cMONO - 0.972963940812728
#
# 2024-09-25 15:06:30,414 - INFO -
#
# 2024-09-25 15:06:30,414 - INFO - reassigning cluster 21
#
# 2024-09-25 15:06:30,415 - INFO - from CD8_TEM - 0.989574500118348 to CD8_TEMRA - 0.989233525586851
#
# 2024-09-25 15:06:30,415 - INFO -
#
# 2024-09-25 15:06:30,416 - INFO - reassigning cluster 29
#
# 2024-09-25 15:06:30,416 - INFO - from PB - 0.994272047438457 to B_CELL - 0.785877527799733
#
# 2024-09-25 15:06:30,416 - INFO -
#
# 2024-09-25 15:06:30,417 - INFO - reassigning cluster 33
#
# 2024-09-25 15:06:30,417 - INFO - from inMONO - 0.770724419423506 to MONO - 0.752646108293388
#
# 2024-09-25 15:06:30,417 - INFO -
#
# 2024-09-25 15:06:30,418 - INFO - reassigning cluster 34
#
# 2024-09-25 15:06:30,418 - INFO - from CD4_TNAIVE - 0.855413420964537 to CD4_T - 0.850914426953445
#
# 2024-09-25 15:06:30,419 - INFO -
#
# 2024-09-25 15:06:35,418 - INFO - Checking the reassignments and writing the set of final flagged clusters. Here we are also checking that the second assignment score was not too far away from the first (distance of 0.05).
#
# 2024-09-25 15:06:35,498 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:06:35,499 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:06:35,499 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:06:35,570 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:06:35,571 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:06:35,595 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:06:35,595 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:06:40,608 - INFO - The reassigned clusters that did not pass the second check are being assigned back to their highest cosine similarity score.
#
# 2024-09-25 15:06:40,611 - INFO - reassigning cluster 13
#
# 2024-09-25 15:06:40,611 - INFO - from CD16_NK - 0.936893974191022 to NK - 0.938091099859113
#
# 2024-09-25 15:06:40,612 - INFO -
#
# 2024-09-25 15:06:40,612 - INFO - reassigning cluster 29
#
# 2024-09-25 15:06:40,612 - INFO - from B_CELL - 0.785877527799733 to PB - 0.994272047438457
#
# 2024-09-25 15:06:40,613 - INFO -
#
# 2024-09-25 15:06:40,613 - INFO - reassigning cluster 33
#
# 2024-09-25 15:06:40,613 - INFO - from MONO - 0.752646108293388 to inMONO - 0.770724419423506
#
# 2024-09-25 15:06:40,613 - INFO -
#
# 2024-09-25 15:06:40,613 - INFO - reassigning cluster 34
#
# 2024-09-25 15:06:40,614 - INFO - from CD4_T - 0.850914426953445 to CD4_TNAIVE - 0.855413420964537
#
# 2024-09-25 15:06:40,614 - INFO -
#
# 2024-09-25 15:06:40,677 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:06:41,211 - INFO - Calculating the frequency of each sample in each cluster.
#
# 2024-09-25 15:06:45,005 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:06:58,039 - INFO - Running UMAP
#
# 2024-09-25 15:11:38,560 - INFO - UMAP calculation took: 4.6752948641777
#
# 2024-09-25 15:11:55,456 - INFO - Writing output files.
#
# 2024-09-25 15:12:10,560 - INFO - Returning data.
#
# 2024-09-25 15:12:10,562 - INFO - Processing not filtered
#
# 2024-09-25 15:12:10,562 - INFO - Min frequency was not provided, we are calculating cluster size based on all events.
#
# 2024-09-25 15:12:13,696 - INFO - Assigning clusters to cell types.
#
# 2024-09-25 15:12:18,959 - INFO - Checking cell population assignments and writing the set of flagged clusters.
#
# 2024-09-25 15:12:19,033 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:12:19,034 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:12:19,036 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:12:19,106 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:12:19,111 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:12:24,122 - INFO - Reassigning flagged clusters to cell types with the second highest cosine similarity score.
#
# 2024-09-25 15:12:24,125 - INFO - reassigning cluster 13
#
# 2024-09-25 15:12:24,125 - INFO - from NK - 0.938091099859113 to CD16_NK - 0.936893974191022
#
# 2024-09-25 15:12:24,126 - INFO -
#
# 2024-09-25 15:12:24,126 - INFO - reassigning cluster 19
#
# 2024-09-25 15:12:24,127 - INFO - from cMONO - 0.973017988175066 to CD33hi_cMONO - 0.972963940812728
#
# 2024-09-25 15:12:24,127 - INFO -
#
# 2024-09-25 15:12:24,127 - INFO - reassigning cluster 21
#
# 2024-09-25 15:12:24,128 - INFO - from CD8_TEM - 0.989574500118348 to CD8_TEMRA - 0.989233525586851
#
# 2024-09-25 15:12:24,128 - INFO -
#
# 2024-09-25 15:12:24,128 - INFO - reassigning cluster 29
#
# 2024-09-25 15:12:24,129 - INFO - from PB - 0.994272047438457 to B_CELL - 0.785877527799733
#
# 2024-09-25 15:12:24,129 - INFO -
#
# 2024-09-25 15:12:24,129 - INFO - reassigning cluster 33
#
# 2024-09-25 15:12:24,129 - INFO - from inMONO - 0.770724419423506 to MONO - 0.752646108293388
#
# 2024-09-25 15:12:24,130 - INFO -
#
# 2024-09-25 15:12:24,130 - INFO - reassigning cluster 34
#
# 2024-09-25 15:12:24,130 - INFO - from CD4_TNAIVE - 0.855413420964537 to CD4_T - 0.850914426953445
#
# 2024-09-25 15:12:24,131 - INFO -
#
# 2024-09-25 15:12:24,131 - INFO - reassigning cluster 31
#
# 2024-09-25 15:12:24,132 - INFO - from B_NAIVE - 0.722180165682372 to B_CELL - 0.718863023831864
#
# 2024-09-25 15:12:24,132 - INFO -
#
# 2024-09-25 15:12:29,132 - INFO - Checking the reassignments and writing the set of final flagged clusters. Here we are also checking that the second assignment score was not too far away from the first (distance of 0.05).
#
# 2024-09-25 15:12:29,236 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:12:29,237 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:12:29,237 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:12:29,283 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:12:29,284 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:12:29,298 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:12:29,298 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:12:34,311 - INFO - The reassigned clusters that did not pass the second check are being assigned back to their highest cosine similarity score.
#
# 2024-09-25 15:12:34,315 - INFO - reassigning cluster 13
#
# 2024-09-25 15:12:34,315 - INFO - from CD16_NK - 0.936893974191022 to NK - 0.938091099859113
#
# 2024-09-25 15:12:34,316 - INFO -
#
# 2024-09-25 15:12:34,317 - INFO - reassigning cluster 29
#
# 2024-09-25 15:12:34,317 - INFO - from B_CELL - 0.785877527799733 to PB - 0.994272047438457
#
# 2024-09-25 15:12:34,318 - INFO -
#
# 2024-09-25 15:12:34,318 - INFO - reassigning cluster 33
#
# 2024-09-25 15:12:34,318 - INFO - from MONO - 0.752646108293388 to inMONO - 0.770724419423506
#
# 2024-09-25 15:12:34,319 - INFO -
#
# 2024-09-25 15:12:34,319 - INFO - reassigning cluster 34
#
# 2024-09-25 15:12:34,320 - INFO - from CD4_T - 0.850914426953445 to CD4_TNAIVE - 0.855413420964537
#
# 2024-09-25 15:12:34,320 - INFO -
#
# 2024-09-25 15:12:34,320 - INFO - reassigning cluster 31
#
# 2024-09-25 15:12:34,321 - INFO - from B_CELL - 0.718863023831864 to B_NAIVE - 0.722180165682372
#
# 2024-09-25 15:12:34,321 - INFO -
#
# 2024-09-25 15:12:34,380 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:12:35,113 - INFO - Calculating the frequency of each sample in each cluster.
#
# 2024-09-25 15:12:39,637 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:12:51,144 - INFO - Running UMAP
#
# 2024-09-25 15:18:33,139 - INFO - UMAP calculation took: 5.69990835189819
#
# 2024-09-25 15:18:49,788 - INFO - Writing output files.
#
# 2024-09-25 15:19:04,988 - INFO - Returning data.
#
# 2024-09-25 15:19:07,991 - INFO - Time: 2024-09-25 15:19:07.98874
#
# 2024-09-25 15:19:07,993 - INFO - Processing k 30.
#
# 2024-09-25 15:19:07,993 - INFO - Processing filtered 0.05
#
# 2024-09-25 15:19:07,994 - INFO - Minimum percentage of 0.05 was provided so we are calculating cluster sizes as percentag of total, filtering out events belonging to clusters under that size, and then re-calculating cluster sizes
#
# 2024-09-25 15:19:13,097 - INFO - Assigning clusters to cell types.
#
# 2024-09-25 15:19:18,301 - INFO - Checking cell population assignments and writing the set of flagged clusters.
#
# 2024-09-25 15:19:18,386 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:19:18,387 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:19:18,387 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:19:18,427 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:19:18,428 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:19:23,439 - INFO - Reassigning flagged clusters to cell types with the second highest cosine similarity score.
#
# 2024-09-25 15:19:23,441 - INFO - reassigning cluster 12
#
# 2024-09-25 15:19:23,441 - INFO - from cMONO - 0.975000071374926 to CD33hi_cMONO - 0.974735812301509
#
# 2024-09-25 15:19:23,442 - INFO -
#
# 2024-09-25 15:19:23,442 - INFO - reassigning cluster 13
#
# 2024-09-25 15:19:23,443 - INFO - from NK - 0.936810674745575 to CD16_NK - 0.935533179360877
#
# 2024-09-25 15:19:23,443 - INFO -
#
# 2024-09-25 15:19:23,444 - INFO - reassigning cluster 15
#
# 2024-09-25 15:19:23,444 - INFO - from TREG - 0.993772313732484 to FOXP3lo_TREG - 0.990758849232813
#
# 2024-09-25 15:19:23,445 - INFO -
#
# 2024-09-25 15:19:23,446 - INFO - reassigning cluster 21
#
# 2024-09-25 15:19:23,446 - INFO - from CD8_TEM - 0.989813549890055 to CD8_TEMRA - 0.989077261317208
#
# 2024-09-25 15:19:23,447 - INFO -
#
# 2024-09-25 15:19:23,447 - INFO - reassigning cluster 26
#
# 2024-09-25 15:19:23,447 - INFO - from transDC - 0.945992596804629 to DC - 0.869826975867209
#
# 2024-09-25 15:19:23,448 - INFO -
#
# 2024-09-25 15:19:23,448 - INFO - reassigning cluster 29
#
# 2024-09-25 15:19:23,448 - INFO - from PB - 0.993651932352517 to B_CELL - 0.785265659174757
#
# 2024-09-25 15:19:23,449 - INFO -
#
# 2024-09-25 15:19:23,449 - INFO - reassigning cluster 33
#
# 2024-09-25 15:19:23,449 - INFO - from inMONO - 0.770736546786345 to MONO - 0.752662364136353
#
# 2024-09-25 15:19:23,450 - INFO -
#
# 2024-09-25 15:19:23,450 - INFO - reassigning cluster 34
#
# 2024-09-25 15:19:23,451 - INFO - from CD4_TNAIVE - 0.855576380091556 to CD4_T - 0.850648083473897
#
# 2024-09-25 15:19:23,451 - INFO -
#
# 2024-09-25 15:19:28,453 - INFO - Checking the reassignments and writing the set of final flagged clusters. Here we are also checking that the second assignment score was not too far away from the first (distance of 0.05).
#
# 2024-09-25 15:19:28,545 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:19:28,545 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:19:28,546 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:19:28,652 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:19:28,653 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:19:28,667 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:19:28,667 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:19:33,679 - INFO - The reassigned clusters that did not pass the second check are being assigned back to their highest cosine similarity score.
#
# 2024-09-25 15:19:33,690 - INFO - reassigning cluster 13
#
# 2024-09-25 15:19:33,690 - INFO - from CD16_NK - 0.935533179360877 to NK - 0.936810674745575
#
# 2024-09-25 15:19:33,690 - INFO -
#
# 2024-09-25 15:19:33,691 - INFO - reassigning cluster 29
#
# 2024-09-25 15:19:33,691 - INFO - from B_CELL - 0.785265659174757 to PB - 0.993651932352517
#
# 2024-09-25 15:19:33,691 - INFO -
#
# 2024-09-25 15:19:33,692 - INFO - reassigning cluster 33
#
# 2024-09-25 15:19:33,693 - INFO - from MONO - 0.752662364136353 to inMONO - 0.770736546786345
#
# 2024-09-25 15:19:33,694 - INFO -
#
# 2024-09-25 15:19:33,694 - INFO - reassigning cluster 34
#
# 2024-09-25 15:19:33,695 - INFO - from CD4_T - 0.850648083473897 to CD4_TNAIVE - 0.855576380091556
#
# 2024-09-25 15:19:33,695 - INFO -
#
# 2024-09-25 15:19:33,695 - INFO - reassigning cluster 26
#
# 2024-09-25 15:19:33,696 - INFO - from DC - 0.869826975867209 to transDC - 0.945992596804629
#
# 2024-09-25 15:19:33,696 - INFO -
#
# 2024-09-25 15:19:33,751 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:19:34,305 - INFO - Calculating the frequency of each sample in each cluster.
#
# 2024-09-25 15:19:38,010 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:19:49,065 - INFO - Running UMAP
#
# 2024-09-25 15:24:23,021 - INFO - UMAP calculation took: 4.5659240325292
#
# 2024-09-25 15:24:39,709 - INFO - Writing output files.
#
# 2024-09-25 15:24:54,806 - INFO - Returning data.
#
# 2024-09-25 15:24:54,808 - INFO - Processing not filtered
#
# 2024-09-25 15:24:54,808 - INFO - Min frequency was not provided, we are calculating cluster size based on all events.
#
# 2024-09-25 15:24:58,931 - INFO - Assigning clusters to cell types.
#
# 2024-09-25 15:25:04,291 - INFO - Checking cell population assignments and writing the set of flagged clusters.
#
# 2024-09-25 15:25:04,391 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:25:04,392 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:25:04,394 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:25:04,499 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:25:04,500 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:25:09,512 - INFO - Reassigning flagged clusters to cell types with the second highest cosine similarity score.
#
# 2024-09-25 15:25:09,517 - INFO - reassigning cluster 12
#
# 2024-09-25 15:25:09,518 - INFO - from cMONO - 0.975000071374926 to CD33hi_cMONO - 0.974735812301509
#
# 2024-09-25 15:25:09,518 - INFO -
#
# 2024-09-25 15:25:09,518 - INFO - reassigning cluster 13
#
# 2024-09-25 15:25:09,518 - INFO - from NK - 0.936810674745575 to CD16_NK - 0.935533179360877
#
# 2024-09-25 15:25:09,519 - INFO -
#
# 2024-09-25 15:25:09,519 - INFO - reassigning cluster 15
#
# 2024-09-25 15:25:09,519 - INFO - from TREG - 0.993772313732484 to FOXP3lo_TREG - 0.990758849232813
#
# 2024-09-25 15:25:09,519 - INFO -
#
# 2024-09-25 15:25:09,520 - INFO - reassigning cluster 21
#
# 2024-09-25 15:25:09,520 - INFO - from CD8_TEM - 0.989813549890055 to CD8_TEMRA - 0.989077261317208
#
# 2024-09-25 15:25:09,520 - INFO -
#
# 2024-09-25 15:25:09,520 - INFO - reassigning cluster 26
#
# 2024-09-25 15:25:09,521 - INFO - from transDC - 0.945992596804629 to DC - 0.869826975867209
#
# 2024-09-25 15:25:09,521 - INFO -
#
# 2024-09-25 15:25:09,521 - INFO - reassigning cluster 29
#
# 2024-09-25 15:25:09,522 - INFO - from PB - 0.993651932352517 to B_CELL - 0.785265659174757
#
# 2024-09-25 15:25:09,522 - INFO -
#
# 2024-09-25 15:25:09,523 - INFO - reassigning cluster 33
#
# 2024-09-25 15:25:09,523 - INFO - from inMONO - 0.770736546786345 to MONO - 0.752662364136353
#
# 2024-09-25 15:25:09,523 - INFO -
#
# 2024-09-25 15:25:09,523 - INFO - reassigning cluster 34
#
# 2024-09-25 15:25:09,524 - INFO - from CD4_TNAIVE - 0.855576380091556 to CD4_T - 0.850648083473897
#
# 2024-09-25 15:25:09,524 - INFO -
#
# 2024-09-25 15:25:09,524 - INFO - reassigning cluster 31
#
# 2024-09-25 15:25:09,524 - INFO - from B_NAIVE - 0.721809310469642 to B_CELL - 0.718378013179267
#
# 2024-09-25 15:25:09,525 - INFO -
#
# 2024-09-25 15:25:14,522 - INFO - Checking the reassignments and writing the set of final flagged clusters. Here we are also checking that the second assignment score was not too far away from the first (distance of 0.05).
#
# 2024-09-25 15:25:14,616 - INFO - Adding missing grouping variables: `population_name`, `cluster_name`,
#
# 2024-09-25 15:25:14,617 - INFO - `frequency`, `percent`, `assignment.score.1`, `assignment.1`,
#
# 2024-09-25 15:25:14,617 - INFO - `assignment.score.2`, `assignment.2`
#
# 2024-09-25 15:25:14,671 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:25:14,671 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:25:14,685 - INFO - Joining with `by = join_by(population_name, cluster_name, frequency, percent,
#
# 2024-09-25 15:25:14,686 - INFO - assignment.score.1, assignment.1, assignment.score.2, assignment.2)`
#
# 2024-09-25 15:25:19,701 - INFO - The reassigned clusters that did not pass the second check are being assigned back to their highest cosine similarity score.
#
# 2024-09-25 15:25:19,705 - INFO - reassigning cluster 13
#
# 2024-09-25 15:25:19,707 - INFO - from CD16_NK - 0.935533179360877 to NK - 0.936810674745575
#
# 2024-09-25 15:25:19,707 - INFO -
#
# 2024-09-25 15:25:19,708 - INFO - reassigning cluster 29
#
# 2024-09-25 15:25:19,708 - INFO - from B_CELL - 0.785265659174757 to PB - 0.993651932352517
#
# 2024-09-25 15:25:19,709 - INFO -
#
# 2024-09-25 15:25:19,709 - INFO - reassigning cluster 33
#
# 2024-09-25 15:25:19,710 - INFO - from MONO - 0.752662364136353 to inMONO - 0.770736546786345
#
# 2024-09-25 15:25:19,710 - INFO -
#
# 2024-09-25 15:25:19,711 - INFO - reassigning cluster 34
#
# 2024-09-25 15:25:19,711 - INFO - from CD4_T - 0.850648083473897 to CD4_TNAIVE - 0.855576380091556
#
# 2024-09-25 15:25:19,711 - INFO -
#
# 2024-09-25 15:25:19,712 - INFO - reassigning cluster 31
#
# 2024-09-25 15:25:19,712 - INFO - from B_CELL - 0.718378013179267 to B_NAIVE - 0.721809310469642
#
# 2024-09-25 15:25:19,712 - INFO -
#
# 2024-09-25 15:25:19,713 - INFO - reassigning cluster 26
#
# 2024-09-25 15:25:19,713 - INFO - from DC - 0.869826975867209 to transDC - 0.945992596804629
#
# 2024-09-25 15:25:19,713 - INFO -
#
# 2024-09-25 15:25:19,794 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:25:20,354 - INFO - Calculating the frequency of each sample in each cluster.
#
# 2024-09-25 15:25:24,180 - INFO - Joining with `by = join_by(cluster_name)`
#
# 2024-09-25 15:25:35,801 - INFO - Running UMAP
#
# 2024-09-25 15:30:09,163 - INFO - UMAP calculation took: 4.55601746638616
#
# 2024-09-25 15:30:26,075 - INFO - Writing output files.
#
# 2024-09-25 15:30:43,151 - INFO - Returning data.
#
# 2024-09-25 15:30:43,154 - INFO - Processing took 24.5511029005051
#
# 2024-09-25 15:30:43,155 - INFO - Error in make_all_inital_qc_plots_for_all_k_values(project_code = project_code,  :
#
# 2024-09-25 15:30:43,156 - INFO -   unused argument (cluster_filename_suffix = clustering_file_name_suffix)
#
# 2024-09-25 15:30:43,156 - INFO - Calls: process_all
#
# 2024-09-25 15:30:43,158 - INFO - In addition: Warning messages:
#
# 2024-09-25 15:30:43,158 - INFO - 1: In readFCSdata(con, offsets, txt, transformation, which.lines, scale,  :
#
# 2024-09-25 15:30:43,158 - INFO -   Some data values of 'Time' channel exceed its $PnR value 262144 and will be truncated!
#
# 2024-09-25 15:30:43,158 - INFO -  To avoid truncation, either fix $PnR before generating FCS or set 'truncate_max_range = FALSE'
#
# 2024-09-25 15:30:43,160 - INFO - 2: In tokuprofile::get_panel(fcs.filedir = clustering_data$fcs.dir) :
#
# 2024-09-25 15:30:43,160 - INFO -   The following standard markers are missing from the panel:CD8A, CD57, KLRG1, GRB, CD86, CD28, CD161, CD74, ICOS, LOX1, IGG4
#
# 2024-09-25 15:30:43,161 - INFO - 3: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-25 15:30:43,161 - INFO -   The cell populations T_CELL are in your cell.pops.list but not in cell.pop.groups.
#
# 2024-09-25 15:30:43,161 - INFO - 4: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-25 15:30:43,162 - INFO -   The cell populations NEUTROPHIL, CD16hi_NEUTROPHIL, CD16lo_NEUTROPHIL, BASOPHIL, FOXP3hi_TREG, FOXP3lo_TREG, CD33lo_cMONO, CD33hi_cMONO are in your cell.pop.groups but not your cell.pops.list.
#
# 2024-09-25 15:30:43,162 - INFO - 5: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-25 15:30:43,163 - INFO -   The markers CD20, CD66B, CD8A are in your cell.pops.list are not in your col.names.
#
# 2024-09-25 15:30:43,164 - INFO - 6: In safely_merge_annotations(tab, sample.annotations, by = by) :
#
# 2024-09-25 15:30:43,164 - INFO -   Removing project_code,benchling_sample_name,is_control,subject_name from annotations because it's already present in tab
#
# 2024-09-25 15:30:43,165 - INFO - 7: In safely_merge_annotations(tab, sample.annotations, by = by) :
#
# 2024-09-25 15:30:43,165 - INFO -   Removing project_code,benchling_sample_name,is_control,subject_name from annotations because it's already present in tab
#
# 2024-09-25 15:30:43,165 - INFO - 8: In safely_merge_annotations(tab, sample.annotations, by = by) :
#
# 2024-09-25 15:30:43,166 - INFO -   Removing project_code,benchling_sample_name,is_control,subject_name from annotations because it's already present in tab
#
# 2024-09-25 15:30:43,167 - INFO - 9: In safely_merge_annotations(tab, sample.annotations, by = by) :
#
# 2024-09-25 15:30:43,167 - INFO -   Removing project_code,benchling_sample_name,is_control,subject_name from annotations because it's already present in tab
#
# 2024-09-25 15:30:43,167 - INFO - Execution halted
#
# 2024-09-25 15:31:33,152 - INFO - Clustering script run
# 2024-09-25 17:40:38,027| ERROR   | Socket exception: Operation timed out (60)
# 2024-09-25 17:40:38,027 - ERROR - Socket exception: Operation timed out (60)

# %%
clustering.run_clustering(overwrite=False)
# Out:
# 2024-09-26 13:41:03,335 - WARNING - Clustering fcs set s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_fcs already exists
# 2024-09-26 13:41:03,335 - WARNING - Clustering fcs set s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_fcs already exists
# 2024-09-26 13:41:03,337 - WARNING - Clustering fcs input s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_inputs already exists
# 2024-09-26 13:41:03,337 - WARNING - Clustering fcs input s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_inputs already exists
# 2024-09-26 13:41:03,338 - WARNING - Clustering results s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_results already exists
# 2024-09-26 13:41:03,338 - WARNING - Clustering results s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_results already exists
# 2024-09-26 13:41:03,338 - INFO - Running R clustering script
# 2024-09-26 13:41:03,338 - INFO - Running R clustering script
# 2024-09-26 13:41:03,652 - INFO - Loading required package: tidyverse
#
# 2024-09-26 13:41:03,652 - INFO - Loading required package: tidyverse
#
# 2024-09-26 13:41:04,241 - INFO - ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
#
# 2024-09-26 13:41:04,241 - INFO - ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
#
# 2024-09-26 13:41:04,242 - INFO - ✔ dplyr     1.1.4     ✔ readr     2.1.5
#
# 2024-09-26 13:41:04,242 - INFO - ✔ dplyr     1.1.4     ✔ readr     2.1.5
#
# 2024-09-26 13:41:04,243 - INFO - ✔ forcats   1.0.0     ✔ stringr   1.5.1
#
# 2024-09-26 13:41:04,243 - INFO - ✔ forcats   1.0.0     ✔ stringr   1.5.1
#
# 2024-09-26 13:41:04,243 - INFO - ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
#
# 2024-09-26 13:41:04,243 - INFO - ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
#
# 2024-09-26 13:41:04,244 - INFO - ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
#
# 2024-09-26 13:41:04,244 - INFO - ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
#
# 2024-09-26 13:41:04,244 - INFO - ✔ purrr     1.0.2
#
# 2024-09-26 13:41:04,244 - INFO - ✔ purrr     1.0.2
#
# 2024-09-26 13:41:04,289 - INFO - ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
#
# 2024-09-26 13:41:04,289 - INFO - ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
#
# 2024-09-26 13:41:04,290 - INFO - ✖ dplyr::filter() masks stats::filter()
#
# 2024-09-26 13:41:04,290 - INFO - ✖ dplyr::filter() masks stats::filter()
#
# 2024-09-26 13:41:04,291 - INFO - ✖ dplyr::lag()    masks stats::lag()
#
# 2024-09-26 13:41:04,291 - INFO - ✖ dplyr::lag()    masks stats::lag()
#
# 2024-09-26 13:41:04,291 - INFO - ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# 2024-09-26 13:41:04,291 - INFO - ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# 2024-09-26 13:41:04,292 - INFO - Loading required package: flowCore
#
# 2024-09-26 13:41:04,292 - INFO - Loading required package: flowCore
#
# 2024-09-26 13:41:05,041 - INFO - Loading required package: tokuprofile
#
# 2024-09-26 13:41:05,041 - INFO - Loading required package: tokuprofile
#
# 2024-09-26 13:41:05,088 - INFO - Loading required package: Spectre
#
# 2024-09-26 13:41:05,088 - INFO - Loading required package: Spectre
#
# 2024-09-26 13:41:05,097 - INFO - Loading required package: vroom
#
# 2024-09-26 13:41:05,097 - INFO - Loading required package: vroom
#
# 2024-09-26 13:41:05,187 - INFO -
#
# 2024-09-26 13:41:05,187 - INFO -
#
# 2024-09-26 13:41:05,188 - INFO - Attaching package: ‘vroom’
#
# 2024-09-26 13:41:05,188 - INFO - Attaching package: ‘vroom’
#
# 2024-09-26 13:41:05,189 - INFO -
#
# 2024-09-26 13:41:05,189 - INFO -
#
# 2024-09-26 13:41:05,189 - INFO - The following objects are masked from ‘package:readr’:
#
# 2024-09-26 13:41:05,189 - INFO - The following objects are masked from ‘package:readr’:
#
# 2024-09-26 13:41:05,189 - INFO -
#
# 2024-09-26 13:41:05,189 - INFO -
#
# 2024-09-26 13:41:05,190 - INFO -     as.col_spec, col_character, col_date, col_datetime, col_double,
#
# 2024-09-26 13:41:05,190 - INFO -     as.col_spec, col_character, col_date, col_datetime, col_double,
#
# 2024-09-26 13:41:05,190 - INFO -     col_factor, col_guess, col_integer, col_logical, col_number,
#
# 2024-09-26 13:41:05,190 - INFO -     col_factor, col_guess, col_integer, col_logical, col_number,
#
# 2024-09-26 13:41:05,191 - INFO -     col_skip, col_time, cols, cols_condense, cols_only, date_names,
#
# 2024-09-26 13:41:05,191 - INFO -     col_skip, col_time, cols, cols_condense, cols_only, date_names,
#
# 2024-09-26 13:41:05,191 - INFO -     date_names_lang, date_names_langs, default_locale, fwf_cols,
#
# 2024-09-26 13:41:05,191 - INFO -     date_names_lang, date_names_langs, default_locale, fwf_cols,
#
# 2024-09-26 13:41:05,192 - INFO -     fwf_empty, fwf_positions, fwf_widths, locale, output_column,
#
# 2024-09-26 13:41:05,192 - INFO -     fwf_empty, fwf_positions, fwf_widths, locale, output_column,
#
# 2024-09-26 13:41:05,192 - INFO -     problems, spec
#
# 2024-09-26 13:41:05,192 - INFO -     problems, spec
#
# 2024-09-26 13:41:05,192 - INFO -
#
# 2024-09-26 13:41:05,192 - INFO -
#
# 2024-09-26 13:41:05,193 - INFO - Loading required package: caret
#
# 2024-09-26 13:41:05,193 - INFO - Loading required package: caret
#
# 2024-09-26 13:41:05,193 - INFO - Loading required package: lattice
#
# 2024-09-26 13:41:05,193 - INFO - Loading required package: lattice
#
# 2024-09-26 13:41:06,096 - INFO -
#
# 2024-09-26 13:41:06,096 - INFO -
#
# 2024-09-26 13:41:06,097 - INFO - Attaching package: ‘caret’
#
# 2024-09-26 13:41:06,097 - INFO - Attaching package: ‘caret’
#
# 2024-09-26 13:41:06,097 - INFO -
#
# 2024-09-26 13:41:06,097 - INFO -
#
# 2024-09-26 13:41:06,098 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-26 13:41:06,098 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-26 13:41:06,098 - INFO -
#
# 2024-09-26 13:41:06,098 - INFO -
#
# 2024-09-26 13:41:06,099 - INFO -     lift
#
# 2024-09-26 13:41:06,099 - INFO -     lift
#
# 2024-09-26 13:41:06,099 - INFO -
#
# 2024-09-26 13:41:06,099 - INFO -
#
# 2024-09-26 13:41:06,100 - INFO - Loading required package: ggridges
#
# 2024-09-26 13:41:06,100 - INFO - Loading required package: ggridges
#
# 2024-09-26 13:41:06,110 - INFO - Loading required package: data.table
#
# 2024-09-26 13:41:06,110 - INFO - Loading required package: data.table
#
# 2024-09-26 13:41:06,125 - INFO -
#
# 2024-09-26 13:41:06,125 - INFO -
#
# 2024-09-26 13:41:06,126 - INFO - Attaching package: ‘data.table’
#
# 2024-09-26 13:41:06,126 - INFO - Attaching package: ‘data.table’
#
# 2024-09-26 13:41:06,126 - INFO -
#
# 2024-09-26 13:41:06,126 - INFO -
#
# 2024-09-26 13:41:06,127 - INFO - The following objects are masked from ‘package:lubridate’:
#
# 2024-09-26 13:41:06,127 - INFO - The following objects are masked from ‘package:lubridate’:
#
# 2024-09-26 13:41:06,127 - INFO -
#
# 2024-09-26 13:41:06,127 - INFO -
#
# 2024-09-26 13:41:06,128 - INFO -     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#
# 2024-09-26 13:41:06,128 - INFO -     hour, isoweek, mday, minute, month, quarter, second, wday, week,
#
# 2024-09-26 13:41:06,128 - INFO -     yday, year
#
# 2024-09-26 13:41:06,128 - INFO -     yday, year
#
# 2024-09-26 13:41:06,129 - INFO -
#
# 2024-09-26 13:41:06,129 - INFO -
#
# 2024-09-26 13:41:06,129 - INFO - The following objects are masked from ‘package:dplyr’:
#
# 2024-09-26 13:41:06,129 - INFO - The following objects are masked from ‘package:dplyr’:
#
# 2024-09-26 13:41:06,130 - INFO -
#
# 2024-09-26 13:41:06,130 - INFO -
#
# 2024-09-26 13:41:06,130 - INFO -     between, first, last
#
# 2024-09-26 13:41:06,130 - INFO -     between, first, last
#
# 2024-09-26 13:41:06,131 - INFO -
#
# 2024-09-26 13:41:06,131 - INFO -
#
# 2024-09-26 13:41:06,131 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-26 13:41:06,131 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-26 13:41:06,132 - INFO -
#
# 2024-09-26 13:41:06,132 - INFO -
#
# 2024-09-26 13:41:06,132 - INFO -     transpose
#
# 2024-09-26 13:41:06,132 - INFO -     transpose
#
# 2024-09-26 13:41:06,132 - INFO -
#
# 2024-09-26 13:41:06,132 - INFO -
#
# 2024-09-26 13:41:06,133 - INFO - Warning messages:
#
# 2024-09-26 13:41:06,133 - INFO - Warning messages:
#
# 2024-09-26 13:41:06,133 - INFO - 1: replacing previous import ‘data.table::first’ by ‘dplyr::first’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,133 - INFO - 1: replacing previous import ‘data.table::first’ by ‘dplyr::first’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,133 - INFO - 2: replacing previous import ‘data.table::last’ by ‘dplyr::last’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,133 - INFO - 2: replacing previous import ‘data.table::last’ by ‘dplyr::last’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,134 - INFO - 3: replacing previous import ‘data.table::between’ by ‘dplyr::between’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,134 - INFO - 3: replacing previous import ‘data.table::between’ by ‘dplyr::between’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,134 - INFO - 4: replacing previous import ‘data.table::transpose’ by ‘purrr::transpose’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,134 - INFO - 4: replacing previous import ‘data.table::transpose’ by ‘purrr::transpose’ when loading ‘tokuprofile’
#
# 2024-09-26 13:41:06,177 - INFO - [1] 25 30
#
# 2024-09-26 13:41:06,177 - INFO - [1] 25 30
#
# 2024-09-26 13:41:06,178 - INFO - Data prep started
#
# 2024-09-26 13:41:06,178 - INFO - Data prep started
#
# 2024-09-26 13:41:31,215 - INFO - Joining with `by = join_by(fcsFileId, file_name, populationId, population_name,
#
# 2024-09-26 13:41:31,215 - INFO - Joining with `by = join_by(fcsFileId, file_name, populationId, population_name,
#
# 2024-09-26 13:41:31,221 - INFO - uniquePopulationName, parent_population_name, parentPopulationId, event_count,
#
# 2024-09-26 13:41:31,221 - INFO - uniquePopulationName, parent_population_name, parentPopulationId, event_count,
#
# 2024-09-26 13:41:31,227 - INFO - channel, marker_name, sample_id, sample_name, project_code,
#
# 2024-09-26 13:41:31,227 - INFO - channel, marker_name, sample_id, sample_name, project_code,
#
# 2024-09-26 13:41:31,231 - INFO - benchling_sample_name, sample_type, is_control, timepoint_id, sample_date,
#
# 2024-09-26 13:41:31,231 - INFO - benchling_sample_name, sample_type, is_control, timepoint_id, sample_date,
#
# 2024-09-26 13:41:31,233 - INFO - subject_name, species, condition, subject_properties_dose)`
#
# 2024-09-26 13:41:31,233 - INFO - subject_name, species, condition, subject_properties_dose)`
#
# 2024-09-26 13:41:31,366 - INFO - Preparing fcs files for clustering
#
# 2024-09-26 13:41:31,366 - INFO - Preparing fcs files for clustering
#
# 2024-09-26 13:41:40,585 - INFO - Time: 2024-09-26 13:41:40.583786
#
# 2024-09-26 13:41:40,585 - INFO - Time: 2024-09-26 13:41:40.583786
#
# 2024-09-26 13:41:40,589 - INFO - Processing k 25.
#
# 2024-09-26 13:41:40,589 - INFO - Processing k 25.
#
# 2024-09-26 13:41:40,589 - INFO - Clustering has already been run for k = 25. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:40,589 - INFO - Clustering has already been run for k = 25. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:40,590 - INFO - Time: 2024-09-26 13:41:40.585668
#
# 2024-09-26 13:41:40,590 - INFO - Time: 2024-09-26 13:41:40.585668
#
# 2024-09-26 13:41:40,590 - INFO - Processing k 30.
#
# 2024-09-26 13:41:40,590 - INFO - Processing k 30.
#
# 2024-09-26 13:41:40,591 - INFO - Clustering has already been run for k = 30. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:40,591 - INFO - Clustering has already been run for k = 30. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:43,549 - INFO - Time: 2024-09-26 13:41:43.548417
#
# 2024-09-26 13:41:43,549 - INFO - Time: 2024-09-26 13:41:43.548417
#
# 2024-09-26 13:41:43,550 - INFO - Processing k 25.
#
# 2024-09-26 13:41:43,550 - INFO - Processing k 25.
#
# 2024-09-26 13:41:43,551 - INFO - Processing has already been run for filtered results k = 25. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:43,551 - INFO - Processing has already been run for filtered results k = 25. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:43,551 - INFO - Processing has already been run for k = 25. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:43,551 - INFO - Processing has already been run for k = 25. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:43,552 - INFO - Processing took 2.96379685401917
#
# 2024-09-26 13:41:43,552 - INFO - Processing took 2.96379685401917
#
# 2024-09-26 13:41:46,710 - INFO - Time: 2024-09-26 13:41:46.710364
#
# 2024-09-26 13:41:46,710 - INFO - Time: 2024-09-26 13:41:46.710364
#
# 2024-09-26 13:41:46,711 - INFO - Processing k 30.
#
# 2024-09-26 13:41:46,711 - INFO - Processing k 30.
#
# 2024-09-26 13:41:46,712 - INFO - Processing has already been run for filtered results k = 30. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:46,712 - INFO - Processing has already been run for filtered results k = 30. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:46,712 - INFO - Processing has already been run for k = 30. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:46,712 - INFO - Processing has already been run for k = 30. Set overwrite = TRUE to rerun.
#
# 2024-09-26 13:41:46,713 - INFO - Processing took 6.1249258518219
#
# 2024-09-26 13:41:46,713 - INFO - Processing took 6.1249258518219
#
# 2024-09-26 13:41:46,714 - INFO - Making all initial QC plots for all k values25, 30
#
# 2024-09-26 13:41:46,714 - INFO - Making all initial QC plots for all k values25, 30
#
# 2024-09-26 13:41:46,714 - INFO - Loading the data
#
# 2024-09-26 13:41:46,714 - INFO - Loading the data
#
# 2024-09-26 13:41:50,449 - INFO - Loading required package: scales
#
# 2024-09-26 13:41:50,449 - INFO - Loading required package: scales
#
# 2024-09-26 13:41:50,454 - INFO -
#
# 2024-09-26 13:41:50,454 - INFO -
#
# 2024-09-26 13:41:50,455 - INFO - Attaching package: ‘scales’
#
# 2024-09-26 13:41:50,455 - INFO - Attaching package: ‘scales’
#
# 2024-09-26 13:41:50,455 - INFO -
#
# 2024-09-26 13:41:50,455 - INFO -
#
# 2024-09-26 13:41:50,456 - INFO - The following object is masked from ‘package:vroom’:
#
# 2024-09-26 13:41:50,456 - INFO - The following object is masked from ‘package:vroom’:
#
# 2024-09-26 13:41:50,456 - INFO -
#
# 2024-09-26 13:41:50,456 - INFO -
#
# 2024-09-26 13:41:50,457 - INFO -     col_factor
#
# 2024-09-26 13:41:50,457 - INFO -     col_factor
#
# 2024-09-26 13:41:50,457 - INFO -
#
# 2024-09-26 13:41:50,457 - INFO -
#
# 2024-09-26 13:41:50,458 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-26 13:41:50,458 - INFO - The following object is masked from ‘package:purrr’:
#
# 2024-09-26 13:41:50,458 - INFO -
#
# 2024-09-26 13:41:50,458 - INFO -
#
# 2024-09-26 13:41:50,458 - INFO -     discard
#
# 2024-09-26 13:41:50,458 - INFO -     discard
#
# 2024-09-26 13:41:50,459 - INFO -
#
# 2024-09-26 13:41:50,459 - INFO -
#
# 2024-09-26 13:41:50,459 - INFO - The following object is masked from ‘package:readr’:
#
# 2024-09-26 13:41:50,459 - INFO - The following object is masked from ‘package:readr’:
#
# 2024-09-26 13:41:50,460 - INFO -
#
# 2024-09-26 13:41:50,460 - INFO -
#
# 2024-09-26 13:41:50,460 - INFO -     col_factor
#
# 2024-09-26 13:41:50,460 - INFO -     col_factor
#
# 2024-09-26 13:41:50,461 - INFO -
#
# 2024-09-26 13:41:50,461 - INFO -
#
# 2024-09-26 13:41:50,461 - INFO - Loading required package: colorRamps
#
# 2024-09-26 13:41:50,461 - INFO - Loading required package: colorRamps
#
# 2024-09-26 13:41:50,462 - INFO - Loading required package: ggthemes
#
# 2024-09-26 13:41:50,462 - INFO - Loading required package: ggthemes
#
# 2024-09-26 13:41:50,472 - INFO - Loading required package: RColorBrewer
#
# 2024-09-26 13:41:50,472 - INFO - Loading required package: RColorBrewer
#
# 2024-09-26 13:41:50,567 - INFO - Error in `ggsave()`:
#
# 2024-09-26 13:41:50,567 - INFO - Error in `ggsave()`:
#
# 2024-09-26 13:41:50,568 - INFO - ! Cannot find directory
#
# 2024-09-26 13:41:50,568 - INFO - ! Cannot find directory
#
# 2024-09-26 13:41:50,569 - INFO -   './TST002/fcs/v04/clustering/v01/clustering_results/k25/figs/umap_by_cluster.png'.
#
# 2024-09-26 13:41:50,569 - INFO -   './TST002/fcs/v04/clustering/v01/clustering_results/k25/figs/umap_by_cluster.png'.
#
# 2024-09-26 13:41:50,569 - INFO - ℹ Please supply an existing directory or use `create.dir = TRUE`.
#
# 2024-09-26 13:41:50,569 - INFO - ℹ Please supply an existing directory or use `create.dir = TRUE`.
#
# 2024-09-26 13:41:50,570 - INFO - Backtrace:
#
# 2024-09-26 13:41:50,570 - INFO - Backtrace:
#
# 2024-09-26 13:41:50,570 - INFO -     ▆
#
# 2024-09-26 13:41:50,570 - INFO -     ▆
#
# 2024-09-26 13:41:50,571 - INFO -  1. └─clustR::process_all(...)
#
# 2024-09-26 13:41:50,571 - INFO -  1. └─clustR::process_all(...)
#
# 2024-09-26 13:41:50,571 - INFO -  2.   └─clustR::make_all_inital_qc_plots_for_all_k_values(...)
#
# 2024-09-26 13:41:50,571 - INFO -  2.   └─clustR::make_all_inital_qc_plots_for_all_k_values(...)
#
# 2024-09-26 13:41:50,571 - INFO -  3.     └─clustR::make_all_inital_qc_plots(...)
#
# 2024-09-26 13:41:50,571 - INFO -  3.     └─clustR::make_all_inital_qc_plots(...)
#
# 2024-09-26 13:41:50,572 - INFO -  4.       └─clustR::high_frequency_clusters_plot_all(data_list)
#
# 2024-09-26 13:41:50,572 - INFO -  4.       └─clustR::high_frequency_clusters_plot_all(data_list)
#
# 2024-09-26 13:41:50,572 - INFO -  5.         └─Spectre::make.colour.plot(...)
#
# 2024-09-26 13:41:50,572 - INFO -  5.         └─Spectre::make.colour.plot(...)
#
# 2024-09-26 13:41:50,573 - INFO -  6.           └─ggplot2::ggsave(...)
#
# 2024-09-26 13:41:50,573 - INFO -  6.           └─ggplot2::ggsave(...)
#
# 2024-09-26 13:41:50,573 - INFO -  7.             └─ggplot2:::check_path(path, filename, create.dir)
#
# 2024-09-26 13:41:50,573 - INFO -  7.             └─ggplot2:::check_path(path, filename, create.dir)
#
# 2024-09-26 13:41:50,574 - INFO -  8.               └─cli::cli_abort(...)
#
# 2024-09-26 13:41:50,574 - INFO -  8.               └─cli::cli_abort(...)
#
# 2024-09-26 13:41:50,574 - INFO -  9.                 └─rlang::abort(...)
#
# 2024-09-26 13:41:50,574 - INFO -  9.                 └─rlang::abort(...)
#
# 2024-09-26 13:41:50,574 - INFO - Warning messages:
#
# 2024-09-26 13:41:50,574 - INFO - Warning messages:
#
# 2024-09-26 13:41:50,575 - INFO - 1: In tokuprofile::get_panel(fcs.filedir = clustering_data$fcs.dir) :
#
# 2024-09-26 13:41:50,575 - INFO - 1: In tokuprofile::get_panel(fcs.filedir = clustering_data$fcs.dir) :
#
# 2024-09-26 13:41:50,575 - INFO -   The following standard markers are missing from the panel:CD8A, CD57, KLRG1, GRB, CD86, CD28, CD161, CD74, ICOS, LOX1, IGG4
#
# 2024-09-26 13:41:50,575 - INFO -   The following standard markers are missing from the panel:CD8A, CD57, KLRG1, GRB, CD86, CD28, CD161, CD74, ICOS, LOX1, IGG4
#
# 2024-09-26 13:41:50,576 - INFO - 2: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-26 13:41:50,576 - INFO - 2: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-26 13:41:50,576 - INFO -   The cell populations T_CELL are in your cell.pops.list but not in cell.pop.groups.
#
# 2024-09-26 13:41:50,576 - INFO -   The cell populations T_CELL are in your cell.pops.list but not in cell.pop.groups.
#
# 2024-09-26 13:41:50,576 - INFO - 3: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-26 13:41:50,576 - INFO - 3: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-26 13:41:50,577 - INFO -   The cell populations NEUTROPHIL, CD16hi_NEUTROPHIL, CD16lo_NEUTROPHIL, BASOPHIL, FOXP3hi_TREG, FOXP3lo_TREG, CD33lo_cMONO, CD33hi_cMONO are in your cell.pop.groups but not your cell.pops.list.
#
# 2024-09-26 13:41:50,577 - INFO -   The cell populations NEUTROPHIL, CD16hi_NEUTROPHIL, CD16lo_NEUTROPHIL, BASOPHIL, FOXP3hi_TREG, FOXP3lo_TREG, CD33lo_cMONO, CD33hi_cMONO are in your cell.pop.groups but not your cell.pops.list.
#
# 2024-09-26 13:41:50,577 - INFO - 4: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-26 13:41:50,577 - INFO - 4: In initiate_cell_pops_markers_df(cell.pops.list = cell.pops, col.names = clustering_data$column.names,  :
#
# 2024-09-26 13:41:50,578 - INFO -   The markers CD20, CD66B, CD8A are in your cell.pops.list are not in your col.names.
#
# 2024-09-26 13:41:50,578 - INFO -   The markers CD20, CD66B, CD8A are in your cell.pops.list are not in your col.names.
#
# 2024-09-26 13:41:50,578 - INFO - Execution halted
#
# 2024-09-26 13:41:50,578 - INFO - Execution halted
# ---------------------------------------------------------------------------
# OverwriteNewerCloudError                  Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 clustering.run_clustering(overwrite=False)
#
# File ~/git/shomei/services/backend/shomei/clustering_runner.py:569, in Clustering.run_clustering(self, overwrite)
#     567 self._collect_s3_files()
#     568 self._run_r_clustering_script(overwrite=overwrite)
# --> 569 self._upload_s3_result_files()
#     571 log.info("Clustering script run")
#
# File ~/git/shomei/services/backend/shomei/clustering_runner.py:127, in Clustering._upload_s3_result_files(self)
#     125 def _upload_s3_result_files(self):
# --> 127     CloudPath(self.clustering_s3_results).upload_from(self.clustering_results_directory, force_overwrite_to_cloud=self.overwrite)
#
# File ~/Projects/20240919_dojigiri/.venv/lib/python3.9/site-packages/cloudpathlib/cloudpath.py:931, in CloudPath.upload_from(self, source, force_overwrite_to_cloud)
#     929 if source.is_dir():
#     930     for p in source.iterdir():
# --> 931         (self / p.name).upload_from(p, force_overwrite_to_cloud=force_overwrite_to_cloud)
#     933     return self
#     935 else:
#
# File ~/Projects/20240919_dojigiri/.venv/lib/python3.9/site-packages/cloudpathlib/cloudpath.py:931, in CloudPath.upload_from(self, source, force_overwrite_to_cloud)
#     929 if source.is_dir():
#     930     for p in source.iterdir():
# --> 931         (self / p.name).upload_from(p, force_overwrite_to_cloud=force_overwrite_to_cloud)
#     933     return self
#     935 else:
#
# File ~/Projects/20240919_dojigiri/.venv/lib/python3.9/site-packages/cloudpathlib/cloudpath.py:931, in CloudPath.upload_from(self, source, force_overwrite_to_cloud)
#     929 if source.is_dir():
#     930     for p in source.iterdir():
# --> 931         (self / p.name).upload_from(p, force_overwrite_to_cloud=force_overwrite_to_cloud)
#     933     return self
#     935 else:
#
# File ~/Projects/20240919_dojigiri/.venv/lib/python3.9/site-packages/cloudpathlib/cloudpath.py:941, in CloudPath.upload_from(self, source, force_overwrite_to_cloud)
#     938 else:
#     939     dst = self
# --> 941 dst._upload_file_to_cloud(source, force_overwrite_to_cloud=force_overwrite_to_cloud)
#     943 return dst
#
# File ~/Projects/20240919_dojigiri/.venv/lib/python3.9/site-packages/cloudpathlib/cloudpath.py:1199, in CloudPath._upload_file_to_cloud(self, local_path, force_overwrite_to_cloud)
#    1196     return self
#    1198 # cloud is newer and we are not overwriting
# -> 1199 raise OverwriteNewerCloudError(
#    1200     f"Local file ({self._local}) for cloud path ({self}) is newer in the cloud disk, but "
#    1201     f"is being requested to be uploaded to the cloud. Either (1) redownload changes from the cloud or "
#    1202     f"(2) pass `force_overwrite_to_cloud=True` to "
#    1203     f"overwrite."
#    1204 )
#
# OverwriteNewerCloudError: Local file (/var/folders/_z/fkr4r8sn3w92754gn645dk740000gn/T/tmpfb5fxftv/tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_results/k30/not_filtered/clusters.csv) for cloud path (s3://tokuprofile-teiko/biopharma/TST002/fcs/v04/clustering/v01/clustering_results/k30/not_filtered/clusters.csv) is newer in the cloud disk, but is being requested to be uploaded to the cloud. Either (1) redownload changes from the cloud or (2) pass `force_overwrite_to_cloud=True` to overwrite.
